# %% [markdown]
# # Preparing input from adata to cellphone input
#
# Subanalysis: only healthy donors and Freiburg group Ia CVID donors

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import seaborn as sns
import scanpy as sc
from glob import iglob
import anndata
# requires 'pip install scrublet'
#import scrublet as scr
import os
import sklearn
from sklearn.linear_model import LogisticRegression
import matplotlib as mpl
import scipy
import matplotlib.pyplot as plt
import pickle

# %%
np.random.seed(0)

# %%
# %%bash
#
# pip freeze
# Out:
# aiohttp==3.7.3
# airr==1.3.1
# alabaster==0.7.12
# alembic @ file:///home/conda/feedstock_root/build_artifacts/alembic_1611176215154/work
# anndata @ file:///home/conda/feedstock_root/build_artifacts/anndata_1605539061264/work
# annoy @ file:///home/conda/feedstock_root/build_artifacts/python-annoy_1610271511811/work
# anyio @ file:///home/conda/feedstock_root/build_artifacts/anyio_1610315727443/work/dist
# arboreto==0.1.6
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1610522574055/work
# async-generator==1.10
# async-timeout==3.0.1
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1605083924122/work
# Babel @ file:///home/conda/feedstock_root/build_artifacts/babel_1605182336601/work
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache==1.6.1
# bbknn @ file:///opt/conda/conda-bld/bbknn_1610991770283/work
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1611678357911/work
# blinker==1.4
# bokeh==2.2.3
# boltons==20.2.1
# brotlipy==0.7.0
# cached-property @ file:///tmp/build/80754af9/cached-property_1600785575025/work
# certifi==2020.12.5
# certipy==0.1.3
# cffi @ file:///home/conda/feedstock_root/build_artifacts/cffi_1606601123836/work
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.6.0
# colorama @ file:///home/conda/feedstock_root/build_artifacts/colorama_1602866480661/work
# commonmark==0.9.1
# conda==4.9.2
# conda-package-handling @ file:///home/conda/feedstock_root/build_artifacts/conda-package-handling_1602876795040/work
# cryptography @ file:///home/conda/feedstock_root/build_artifacts/cryptography_1610338667514/work
# cycler==0.10.0
# Cython @ file:///home/conda/feedstock_root/build_artifacts/cython_1613867105642/work
# cytoolz==0.11.0
# dask==2021.2.0
# decorator==4.4.2
# defusedxml==0.6.0
# dill==0.3.3
# distributed==2021.2.0
# docutils @ file:///home/conda/feedstock_root/build_artifacts/docutils_1610127755164/work
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1605121927639/work/dist/entrypoints-0.3-py2.py3-none-any.whl
# et-xmlfile==1.0.1
# fbpca==1.0
# frozendict==1.2
# fsspec==0.8.5
# future==0.18.2
# geosketch==1.2
# get-version==2.1
# h5py @ file:///home/conda/feedstock_root/build_artifacts/h5py_1604753633781/work
# HeapDict==1.0.1
# hyperopt==0.1.2
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1593328102638/work
# imageio==2.9.0
# imagesize==1.2.0
# importlib-metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1610355167281/work
# interlap==0.2.7
# intervaltree==2.1.0
# ipykernel @ file:///home/conda/feedstock_root/build_artifacts/ipykernel_1607737215242/work/dist/ipykernel-5.4.2-py3-none-any.whl
# ipython @ file:///home/conda/feedstock_root/build_artifacts/ipython_1610764430266/work
# ipython-genutils==0.2.0
# ipywidgets @ file:///home/conda/feedstock_root/build_artifacts/ipywidgets_1609995587151/work
# jdcal==1.4.1
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1605054524035/work
# Jinja2==2.11.2
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1612898609989/work
# json5 @ file:///home/conda/feedstock_root/build_artifacts/json5_1600692310011/work
# jsonschema @ file:///home/conda/feedstock_root/build_artifacts/jsonschema_1602551949684/work
# jupyter-client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1610375432619/work
# jupyter-core @ file:///home/conda/feedstock_root/build_artifacts/jupyter_core_1611181604334/work
# jupyter-resource-usage @ file:///home/conda/feedstock_root/build_artifacts/jupyter-resource-usage_1608550684149/work
# jupyter-rsession-proxy==1.2
# jupyter-server @ file:///home/conda/feedstock_root/build_artifacts/jupyter_server_1611092183461/work
# jupyter-server-proxy==1.6.0
# jupyter-telemetry @ file:///home/conda/feedstock_root/build_artifacts/jupyter_telemetry_1605173804246/work
# jupyterhub @ file:///home/conda/feedstock_root/build_artifacts/jupyterhub-feedstock_1607688149914/work
# jupyterlab @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_1610663604779/work
# jupyterlab-pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1601375948261/work
# jupyterlab-server @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_server_1611690648627/work
# jupyterlab-widgets @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_widgets_1609173350931/work
# kiwisolver @ file:///home/conda/feedstock_root/build_artifacts/kiwisolver_1610099769230/work
# legacy-api-wrap==0.0.0
# leidenalg @ file:///home/conda/feedstock_root/build_artifacts/leidenalg_1605889147051/work
# llvmlite==0.35.0
# locket==0.2.1
# loompy==3.0.6
# louvain @ file:///home/conda/feedstock_root/build_artifacts/louvain_1609939902418/work
# Mako @ file:///home/conda/feedstock_root/build_artifacts/mako_1610659158978/work
# mamba @ file:///home/conda/feedstock_root/build_artifacts/mamba_1613160772800/work
# MarkupSafe @ file:///home/conda/feedstock_root/build_artifacts/markupsafe_1610127565888/work
# matplotlib @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-suite_1611858708474/work
# mistune @ file:///home/conda/feedstock_root/build_artifacts/mistune_1610112875388/work
# mock @ file:///home/conda/feedstock_root/build_artifacts/mock_1610094566888/work
# msgpack==1.0.2
# multidict==5.1.0
# multiprocessing-on-dill==3.5.0a4
# natsort @ file:///home/conda/feedstock_root/build_artifacts/natsort_1611580267114/work
# nbclassic @ file:///home/conda/feedstock_root/build_artifacts/nbclassic_1610352513187/work
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1602859080374/work
# nbconvert @ file:///home/conda/feedstock_root/build_artifacts/nbconvert_1605401836768/work
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1611005694671/work
# nbresuse==0.3.6
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1605195931949/work
# networkx @ file:///home/conda/feedstock_root/build_artifacts/networkx_1598210780226/work
# notebook @ file:///home/conda/feedstock_root/build_artifacts/notebook_1610575313697/work
# numba @ file:///home/conda/feedstock_root/build_artifacts/numba_1607010260266/work
# numexpr @ file:///home/conda/feedstock_root/build_artifacts/numexpr_1609341217654/work
# numpy @ file:///home/conda/feedstock_root/build_artifacts/numpy_1612953005674/work
# numpy-groupies==0.9.13
# oauthlib==3.0.1
# olefile @ file:///home/conda/feedstock_root/build_artifacts/olefile_1602866521163/work
# openpyxl==3.0.6
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1607785313469/work
# pamela==1.0.0
# pandas==1.2.2
# pandocfilters==1.4.2
# parasail==1.2.4
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1595548966091/work
# partd==1.1.0
# patsy==0.5.1
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1602535608087/work
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# Pillow @ file:///home/conda/feedstock_root/build_artifacts/pillow_1612816714926/work
# plotly==4.14.3
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1605543085815/work
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1611605286670/work
# psutil @ file:///home/conda/feedstock_root/build_artifacts/psutil_1610127095720/work
# ptyprocess @ file:///home/conda/feedstock_root/build_artifacts/ptyprocess_1609419310487/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# pyarrow==0.16.0
# pycairo==1.20.0
# pycosat @ file:///home/conda/feedstock_root/build_artifacts/pycosat_1610094800877/work
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1593275161868/work
# pycurl==7.43.0.6
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1610742651773/work
# PyJWT @ file:///home/conda/feedstock_root/build_artifacts/pyjwt_1610910308735/work
# pymongo==3.11.3
# pynndescent @ file:///home/conda/feedstock_root/build_artifacts/pynndescent_1612844832048/work
# pyOpenSSL @ file:///home/conda/feedstock_root/build_artifacts/pyopenssl_1608055815057/work
# pyparsing==2.4.7
# PyQt5==5.12.3
# PyQt5-sip==4.19.18
# PyQtChart==5.12
# PyQtWebEngine==5.12.1
# pyrsistent @ file:///home/conda/feedstock_root/build_artifacts/pyrsistent_1610146798212/work
# pysam==0.16.0.1
# pyscenic==0.11.0
# PySocks @ file:///home/conda/feedstock_root/build_artifacts/pysocks_1610291447907/work
# python-dateutil==2.8.1
# python-editor==1.0.4
# python-igraph @ file:///home/conda/feedstock_root/build_artifacts/python-igraph_1609945946184/work
# python-json-logger @ file:///home/conda/feedstock_root/build_artifacts/python-json-logger_1602545356084/work
# python-Levenshtein==0.12.2
# pytoml==0.1.21
# pytz @ file:///home/conda/feedstock_root/build_artifacts/pytz_1608904108784/work
# PyWavelets==1.1.1
# PyYAML==5.4.1
# pyzmq @ file:///home/conda/feedstock_root/build_artifacts/pyzmq_1610965975478/work
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1608156231189/work
# retrying==1.3.3
# rich==9.11.1
# rpy2==3.4.2
# ruamel-yaml-conda @ file:///home/conda/feedstock_root/build_artifacts/ruamel_yaml_1610408218022/work
# ruamel.yaml @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml_1610291375472/work
# ruamel.yaml.clib @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml.clib_1610146840614/work
# scanorama==1.7
# scanpy @ file:///opt/conda/conda-bld/scanpy_1612436375714/work
# scikit-image==0.18.1
# scikit-learn @ file:///home/conda/feedstock_root/build_artifacts/scikit-learn_1611079738450/work
# scipy @ file:///home/conda/feedstock_root/build_artifacts/scipy_1609457852787/work
# scirpy==0.6.1
# scrublet==0.2.3
# scvelo==0.2.3
# scvi-tools==0.8.1
# seaborn @ file:///home/conda/feedstock_root/build_artifacts/seaborn-split_1611834504644/work
# Send2Trash==1.5.0
# setuptools-scm @ file:///home/conda/feedstock_root/build_artifacts/setuptools_scm_1607915826617/work
# simpervisor==0.4
# sinfo @ file:///home/conda/feedstock_root/build_artifacts/sinfo_1597764960136/work
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1590081179328/work
# sniffio @ file:///home/conda/feedstock_root/build_artifacts/sniffio_1610318319305/work
# snowballstemmer @ file:///home/conda/feedstock_root/build_artifacts/snowballstemmer_1611270869511/work
# sortedcontainers==2.3.0
# Sphinx @ file:///home/conda/feedstock_root/build_artifacts/sphinx_1613491625878/work
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==1.0.3
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.4
# SQLAlchemy @ file:///home/conda/feedstock_root/build_artifacts/sqlalchemy_1610127210540/work
# squarify==0.4.3
# statsmodels @ file:///home/conda/feedstock_root/build_artifacts/statsmodels_1612273599609/work
# stdlib-list @ file:///home/conda/feedstock_root/build_artifacts/stdlib-list_1602130019264/work
# tables @ file:///home/conda/feedstock_root/build_artifacts/pytables_1603317058579/work
# tblib==1.7.0
# terminado @ file:///home/conda/feedstock_root/build_artifacts/terminado_1609794172745/work
# testpath==0.4.4
# texttable @ file:///home/conda/feedstock_root/build_artifacts/texttable_1599404337529/work
# threadpoolctl @ file:///tmp/tmp79xdzxkt/threadpoolctl-2.1.0-py3-none-any.whl
# tifffile==2021.2.1
# toml @ file:///home/conda/feedstock_root/build_artifacts/toml_1604308577558/work
# toolz==0.11.1
# torch==1.7.1
# tornado @ file:///home/conda/feedstock_root/build_artifacts/tornado_1610094706440/work
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1610419111160/work
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1602771532708/work
# typing-extensions==3.7.4.3
# tzlocal==2.1
# umap-learn==0.4.6
# urllib3 @ file:///home/conda/feedstock_root/build_artifacts/urllib3_1611695416663/work
# velocyto==0.17.17
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1600965781394/work
# webencodings==0.5.1
# widgetsnbextension @ file:///home/conda/feedstock_root/build_artifacts/widgetsnbextension_1605475534911/work
# yamlordereddictloader==0.4.0
# yarl==1.6.3
# zict==2.0.0
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1603668650351/work

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.0
# sinfo       0.3.1
# -----
# PIL                 8.1.0
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.4
# chardet             3.0.4
# cloudpickle         1.6.0
# colorama            0.4.4
# constants           NA
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.02.0
# dateutil            2.8.1
# decorator           4.4.2
# get_version         2.1
# h5py                3.1.0
# highs_wrapper       NA
# idna                2.10
# igraph              0.8.3
# ipykernel           5.4.2
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.17.2
# jinja2              2.11.2
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.2.2
# jupyterlab_server   2.1.3
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.35.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.52.0
# numexpr             2.7.2
# numpy               1.20.1
# packaging           20.8
# pandas              1.2.2
# parso               0.7.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.14
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pygments            2.7.4
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2020.5
# requests            2.25.1
# ruamel              NA
# scanpy              1.7.0
# scipy               1.6.0
# seaborn             0.11.1
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.24.1
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# statsmodels         0.12.2
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.4.1
# zmq                 21.0.1
# -----
# IPython             7.19.0
# jupyter_client      6.1.11
# jupyter_core        4.7.0
# jupyterlab          3.0.5
# notebook            6.2.0
# -----
# Python 3.8.6 | packaged by conda-forge | (default, Dec 26 2020, 05:05:16) [GCC 9.3.0]
# Linux-4.15.0-112-generic-x86_64-with-glibc2.10
# 60 logical CPU cores, x86_64
# -----
# Session information updated at 2021-03-09 13:38

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202009_CVID_revision/'

# %% [markdown]
# ## Reding the fully analysed object

# %%
# reading the fully analysed object, final annotation in 'cell_type_final', normalised, log tr and scaled in .X (HVG-subsetted)
# norm, log tr in .raw.X, all genes
adata_hvg = sc.read(save_path+'adata_hvg_bbknn_by_sample_validation_cohort_final_manifold_with_annotation_20210217.h5ad')

# %%
adata_hvg.var['feature_types-0'].value_counts()
# Out:
# Gene Expression     2476
# Antibody Capture     145
# nan                    6
# Name: feature_types-0, dtype: int64

# %%
def add_classification_Freiburg(adata_obj, barcode):
    
    curr_donor = adata_obj.obs.loc[barcode, 'donor']
    
    if curr_donor in ['CVID1', 'CVID34', 'CVID37']:
        return('Ia')
    elif curr_donor in ['CVID18','CVID23','CVID29','CVID33','CVID36']:
        return('Ib')
    elif curr_donor in ['CVID3','CVID25']:
        return('II')
    else:
        return('CONTROL')

# %%
adata_hvg.obs['CVID_class_Freiburg'] = adata_hvg.obs['barcode'].apply(lambda x: add_classification_Freiburg(adata_hvg, x))

# %%
sc.pl.umap(adata_hvg, color=['CVID_class_Freiburg'], palette=['white','orange','blue','red'])
# Out:
# ... storing 'CVID_class_Freiburg' as categorical

# %%
adata_hvg
# Out:
# AnnData object with n_obs × n_vars = 95064 × 2627
#     obs: 'batch', 'bh_pval', 'cell_id', 'dataset', 'n_counts', 'n_genes', 'percent_mito', 'sample', 'scrublet_cluster_score', 'scrublet_score', 'stimulation', 'technique', 'is_doublet', 'donor', 'cell_type', 'prelim_annot', 'celltype_predictions', 'probabilities', 'S_score', 'G2M_score', 'phase', 'n_counts_protein', 'n_counts_protein_lognorm', 'louvain', 'barcode', 'Age', 'Sex', 'Age of disease onset', 'Autoimmunity', 'Gastrointestinal disease', 'Lung disease (bronchiectasis)', 'Lymphoadenopathy ', 'Splenomegaly', 'History of hypogammaglobulinemia, IgA deficiency or immunodeficiency in other family members', 'CVID_status', 'GC_celltype_predictions_all_genes', 'probabilities_GC_all_genes', 'CVID_class_Freiburg'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'genome-8', 'n_cells-8', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'GC_celltype_predictions_all_genes_colors', 'cell_type_colors', 'donor_colors', 'hvg', 'neighbors', 'pca', 'phase_colors', 'sample_colors', 'stimulation_colors', 'umap', 'CVID_class_Freiburg_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
# subsetting to only Freiburg class Ia and CONTROL
adata_hvg = adata_hvg[adata_hvg.obs['CVID_class_Freiburg'].isin(['CONTROL','Ib'])].copy()
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
adata_hvg.obs['CVID_class_Freiburg'].value_counts()
# Out:
# CONTROL    37972
# Ib         27321
# Name: CVID_class_Freiburg, dtype: int64

# %%
adata_hvg
# Out:
# AnnData object with n_obs × n_vars = 65293 × 2627
#     obs: 'batch', 'bh_pval', 'cell_id', 'dataset', 'n_counts', 'n_genes', 'percent_mito', 'sample', 'scrublet_cluster_score', 'scrublet_score', 'stimulation', 'technique', 'is_doublet', 'donor', 'cell_type', 'prelim_annot', 'celltype_predictions', 'probabilities', 'S_score', 'G2M_score', 'phase', 'n_counts_protein', 'n_counts_protein_lognorm', 'louvain', 'barcode', 'Age', 'Sex', 'Age of disease onset', 'Autoimmunity', 'Gastrointestinal disease', 'Lung disease (bronchiectasis)', 'Lymphoadenopathy ', 'Splenomegaly', 'History of hypogammaglobulinemia, IgA deficiency or immunodeficiency in other family members', 'CVID_status', 'GC_celltype_predictions_all_genes', 'probabilities_GC_all_genes', 'CVID_class_Freiburg'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'genome-8', 'n_cells-8', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'GC_celltype_predictions_all_genes_colors', 'cell_type_colors', 'donor_colors', 'hvg', 'neighbors', 'pca', 'phase_colors', 'sample_colors', 'stimulation_colors', 'umap', 'CVID_class_Freiburg_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
# reading the raw count data
adata_raw = sc.read(save_path+'adata_raw_filtered_validation_cohort.h5ad')

# %%
# subsetting to only final cells
adata_raw = adata_raw[adata_hvg.obs_names,:].copy()

# %%
adata_raw.obs['cell_type'] = adata_hvg.obs.loc[adata_raw.obs_names,'cell_type']

# %%
# normalising raw counts
sc.pp.normalize_per_cell(adata_raw, counts_per_cell_after=1e4)
# Out:
# normalizing by total count per cell
#     finished (0:00:01): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
# normalised count values
adata_count = anndata.AnnData(X=adata_raw.X, var=adata_raw.var, obs=adata_raw.obs)
t = adata_count.X.toarray().T
# Set cell ids as column index and gene ids as row index
df_expr_matrix = pd.DataFrame(data=t, columns= adata_count.obs.index, index=adata_count.var_names)

# %%
df_expr_matrix
# Out:
# index          TGGCGCAGTCCGAACC-1  GTATTCTTCAACACGT-1  GATCAGTAGAGGACGG-1  \
# index
# RP11-34P13.7                  0.0            0.000000                 0.0
# FO538757.2                    0.0            0.589136                 0.0
# AP006222.2                    0.0            0.000000                 0.0
# RP4-669L17.10                 0.0            0.000000                 0.0
# RP5-857K21.4                  0.0            0.000000                 0.0
# ...                           ...                 ...                 ...
# CTD-2541M15.3                 0.0            0.000000                 0.0
# THEGL                         0.0            0.000000                 0.0
# KIAA1644                      0.0            0.000000                 0.0
# RP11-132A1.3                  0.0            0.000000                 0.0
# RP11-111H13.1                 0.0            0.000000                 0.0
#
# index          GACTGCGCATGAACCT-1  TACTCGCGTTTGCATG-1  GGGCATCGTCCCTTGT-1-1  \
# index
# RP11-34P13.7                  0.0                 0.0                   0.0
# FO538757.2                    0.0                 0.0                   0.0
# AP006222.2                    0.0                 0.0                   0.0
# RP4-669L17.10                 0.0                 0.0                   0.0
# RP5-857K21.4                  0.0                 0.0                   0.0
# ...                           ...                 ...                   ...
# AP006222.2                    0.0                 0.0                 0.0
# RP4-669L17.10                 0.0                 0.0                 0.0
# RP5-857K21.4                  0.0                 0.0                 0.0
# ...                           ...                 ...                 ...
# CTD-2541M15.3                 0.0                 0.0                 0.0
# THEGL                         0.0                 0.0                 0.0
# KIAA1644                      0.0                 0.0                 0.0
# RP11-132A1.3                  0.0                 0.0                 0.0
# RP11-111H13.1                 0.0                 0.0                 0.0
#
# [21749 rows x 65293 columns]

# %%
df_meta = pd.DataFrame(data={'Cell':list(adata_count.obs.index),
                             'cell_type':[ 'celltype_'+str(i) for i in adata_count.obs['cell_type']] })
df_meta.set_index('Cell', inplace=True)
df_meta
# Out:
#                                            cell_type
# Cell
# TGGCGCAGTCCGAACC-1           celltype_NK_CD16_bright
# GTATTCTTCAACACGT-1  celltype_Monocytes_non-classical
# GATCAGTAGAGGACGG-1   celltype_Monocytes_intermediate
# GACTGCGCATGAACCT-1   celltype_Monocytes_intermediate
# TACTCGCGTTTGCATG-1               celltype_iNKT_cells
# ...                                              ...
# TAGCCGGTCTTGTCAT-1             celltype_T4_activated
# GAAATGAGTGCACGAA-1           celltype_NK_CD16_bright
# CGGAGTCGTGTGACCC-1             celltype_T4_activated
# TCGGTAACAGGTCCAC-1   celltype_Monocytes_intermediate
# CAAGTTGCAGGATTGG-1                 celltype_T4_naive
#
# [65293 rows x 1 columns]

# %%
# %%time

# started at 15:09 22.02.2021
# takes a while
# saving for cellphonedb

savepath_meta = save_path + '20210308_cellphonedb_meta_subanalysis_Freiburg_Ib_and_healthy_donors.tsv'
df_meta.to_csv(savepath_meta, sep = '\t')

print('saved metadata, saving counts now')

savepath_counts = save_path + '20210308_cellphonedb_counts_subanalysis_Freiburg_Ib_and_healthy_donors.csv'
df_expr_matrix.to_csv(savepath_counts)
# Out:
# saved metadata, saving counts now
# CPU times: user 36min 9s, sys: 6min 45s, total: 42min 55s
# Wall time: 45min 14s

# %% [markdown]
# # Preparing a table of expression proportions
#
# Matrix of genes (rows) per celltypes (columns) containing the proportion [0-1] of cells in a celltype expressing the gene

# %%
np.unique(adata_hvg.obs['cell_type'], return_counts=True)
# Out:
# (array(['B_cells_memory', 'B_cells_memory_activated', 'B_cells_naive',
#         'B_cells_naive_activated', 'MAIT_cells', 'Macrophages',
#         'Monocytes_classical', 'Monocytes_intermediate',
#         'Monocytes_non-classical', 'NK_CD16_bright',
#         'NK_CD16_bright_activated', 'NK_CD56_bright',
#         'NK_CD56_bright_activated', 'Plasma_cells', 'Precursor_cells',
#         'T4_activated', 'T4_memory', 'T4_naive', 'T8_activated',
#         'T8_naive', 'TCM_CD8+', 'TEM_CD8+', 'TMRA_CD8+', 'T_gd', 'T_regs',
#         'cDC1', 'cDC2', 'iNKT_cells', 'pDC'], dtype=object),
#  array([ 955, 4311, 1404,  783,  912, 2806, 3993, 2608, 1106, 3795,  664,
#          313,  815,  412,  331, 8658, 4806, 4464, 3197, 2249, 1742, 1986,
#          716, 1261, 5200, 4032,  458, 1220,   96]))

# %%
df_expr_matrix_per_cell_type = {}

for ct in np.unique(adata_hvg.obs['cell_type']):
    print(ct)
    curr_subset_of_barcodes = list(adata_hvg[adata_hvg.obs['cell_type'] == ct].obs_names)
    df_expr_matrix_per_cell_type[ct] = df_expr_matrix.loc[:,curr_subset_of_barcodes]
    print(len(curr_subset_of_barcodes), 'cells of this cell type')
    print('subsetted a table of shape', df_expr_matrix_per_cell_type[ct].shape, '\n')
# Out:
# B_cells_memory
# 955 cells of this cell type
# subsetted a table of shape (21749, 955)
#
# B_cells_memory_activated
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# 4311 cells of this cell type
# subsetted a table of shape (21749, 4311)
#
# B_cells_naive
# 1404 cells of this cell type
# subsetted a table of shape (21749, 1404)
#
# B_cells_naive_activated
# 783 cells of this cell type
# subsetted a table of shape (21749, 783)
#
# MAIT_cells
# 912 cells of this cell type
# subsetted a table of shape (21749, 912)
#
# Macrophages
# 2806 cells of this cell type
# subsetted a table of shape (21749, 2806)
#
# Monocytes_classical
# 3993 cells of this cell type
# subsetted a table of shape (21749, 3993)
#
# Monocytes_intermediate
# 2608 cells of this cell type
# subsetted a table of shape (21749, 2608)
#
# Monocytes_non-classical
# 1106 cells of this cell type
# subsetted a table of shape (21749, 1106)
#
# NK_CD16_bright
# 3795 cells of this cell type
# subsetted a table of shape (21749, 3795)
#
# NK_CD16_bright_activated
# 664 cells of this cell type
# subsetted a table of shape (21749, 664)
#
# NK_CD56_bright
# 313 cells of this cell type
# subsetted a table of shape (21749, 313)
#
# NK_CD56_bright_activated
# 815 cells of this cell type
# subsetted a table of shape (21749, 815)
#
# Plasma_cells
# 412 cells of this cell type
# subsetted a table of shape (21749, 412)
#
# Precursor_cells
# 331 cells of this cell type
# subsetted a table of shape (21749, 331)
#
# T4_activated
# 8658 cells of this cell type
# subsetted a table of shape (21749, 8658)
#
# T4_memory
# 4806 cells of this cell type
# subsetted a table of shape (21749, 4806)
#
# T4_naive
# 4464 cells of this cell type
# subsetted a table of shape (21749, 4464)
#
# T8_activated
# 3197 cells of this cell type
# subsetted a table of shape (21749, 3197)
#
# T8_naive
# 2249 cells of this cell type
# subsetted a table of shape (21749, 2249)
#
# TCM_CD8+
# 1742 cells of this cell type
# subsetted a table of shape (21749, 1742)
#
# TEM_CD8+
# 1986 cells of this cell type
# subsetted a table of shape (21749, 1986)
#
# TMRA_CD8+
# 716 cells of this cell type
# subsetted a table of shape (21749, 716)
#
# T_gd
# 1261 cells of this cell type
# subsetted a table of shape (21749, 1261)
#
# T_regs
# 5200 cells of this cell type
# subsetted a table of shape (21749, 5200)
#
# cDC1
# 4032 cells of this cell type
# subsetted a table of shape (21749, 4032)
#
# cDC2
# 458 cells of this cell type
# subsetted a table of shape (21749, 458)
#
# iNKT_cells
# 1220 cells of this cell type
# subsetted a table of shape (21749, 1220)
#
# pDC
# 96 cells of this cell type
# subsetted a table of shape (21749, 96)

# %%
# how many non-zero elements does this row vector contain? in proportion
df_expr_matrix_per_cell_type['T_regs'].astype(bool).sum(axis=1)/df_expr_matrix_per_cell_type['T_regs'].shape[1]
# Out:
# index
# RP11-34P13.7     0.000000
# FO538757.2       0.155192
# AP006222.2       0.001346
# RP4-669L17.10    0.001731
# RP5-857K21.4     0.000000
#                    ...
# CTD-2541M15.3    0.000000
# THEGL            0.000000
# KIAA1644         0.000000
# RP11-132A1.3     0.000000
# RP11-111H13.1    0.000385
# Length: 21749, dtype: float64

# %%
df_percentage_expressed = pd.DataFrame(index = df_expr_matrix.index,
                                      columns=np.unique(adata_hvg.obs['cell_type']))

# %%
for col in df_percentage_expressed.columns:
    print(col)
    df_percentage_expressed.loc[:,col] = df_expr_matrix_per_cell_type[col].astype(bool).sum(axis=1)/df_expr_matrix_per_cell_type[col].shape[1]
# Out:
# B_cells_memory
# B_cells_memory_activated
# B_cells_naive
# B_cells_naive_activated
# MAIT_cells
# Macrophages
# Monocytes_classical
# Monocytes_intermediate
# Monocytes_non-classical
# NK_CD16_bright
# NK_CD16_bright_activated
# NK_CD56_bright
# NK_CD56_bright_activated
# Plasma_cells
# Precursor_cells
# T4_activated
# T4_memory
# T4_naive
# T8_activated
# T8_naive
# TCM_CD8+
# TEM_CD8+
# TMRA_CD8+
# T_gd
# T_regs
# cDC1
# cDC2
# iNKT_cells
# pDC

# %%
df_percentage_expressed
# Out:
#                B_cells_memory  B_cells_memory_activated  B_cells_naive  \
# index
# RP11-34P13.7         0.000000                  0.000000       0.000712
# FO538757.2           0.113089                  0.250522       0.085470
# AP006222.2           0.002094                  0.004175       0.000000
# RP4-669L17.10        0.002094                  0.003016       0.002137
# RP5-857K21.4         0.001047                  0.000000       0.000000
# ...                       ...                       ...            ...
# CTD-2541M15.3        0.000000                  0.000000       0.000000
# THEGL                0.000000                  0.000000       0.000000
# KIAA1644             0.000000                  0.000000       0.000000
# RP11-132A1.3         0.000000                  0.000000       0.000000
# RP11-111H13.1        0.000000                  0.000000       0.000000
#
#                B_cells_naive_activated  MAIT_cells  Macrophages  \
# index
# RP11-34P13.7                  0.000000    0.000000     0.000713
# FO538757.2                    0.077905    0.074561     0.252673
# AP006222.2                    0.000000    0.001096     0.005702
# RP4-669L17.10                 0.001277    0.000000     0.001069
# RP5-857K21.4                  0.000000    0.000000     0.000000
# ...                                ...         ...          ...
# CTD-2541M15.3                 0.000000    0.000000     0.000000
# THEGL                         0.000000    0.000000     0.000356
# KIAA1644                      0.000000    0.000000     0.000000
# RP11-132A1.3                  0.000000    0.000000     0.000000
# RP11-111H13.1                 0.000000    0.000000     0.000356
#
#                Monocytes_classical  Monocytes_intermediate  \
# index
# RP11-34P13.7              0.000250                0.000000
# FO538757.2                0.217881                0.171779
# AP006222.2                0.004257                0.006135
# RP4-669L17.10             0.000000                0.000383
# RP5-857K21.4              0.000751                0.000000
# ...                            ...                     ...
# CTD-2541M15.3             0.000000                0.000000
# THEGL                         0.0            0.000000                 0.0
# KIAA1644                      0.0            0.000000                 0.0
# RP11-132A1.3                  0.0            0.000000                 0.0
# RP11-111H13.1                 0.0            0.000000                 0.0
#
# index          CGGAGTCGTGTGACCC-1  TCGGTAACAGGTCCAC-1  CAAGTTGCAGGATTGG-1
# index
# RP11-34P13.7                  0.0                 0.0                 0.0
# FO538757.2                    0.0                 0.0                 0.0
# AP006222.2                    0.0                 0.0                 0.0
# RP4-669L17.10                 0.0                 0.0                 0.0
# RP5-857K21.4                  0.0                 0.0                 0.0
# ...                           ...                 ...                 ...
# CTD-2541M15.3                 0.0                 0.0                 0.0
# THEGL                         0.0                 0.0                 0.0
# KIAA1644                      0.0                 0.0                 0.0
# RP11-132A1.3                  0.0                 0.0                 0.0
# RP11-111H13.1                 0.0                 0.0                 0.0
#
# [21749 rows x 65293 columns]

# %%
# save 
df_percentage_expressed.to_csv(save_path + 'PercentExpressed_for_cellphone_20210308_subanalysis_Freiburg_Ib_and_healthy_donors.csv')

# %%
save_path
# Out:
# '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202009_CVID_revision/'

# %% [markdown]
# # Creating a joint DE table out of limma outputs

# %%
# reading in limma tables for all the cell types

limma_DE_tables = {}

for ct in np.unique(adata_hvg.obs['cell_type']):
    print(ct)
    
    limma_DE_tables[ct] = pd.read_csv('/home/jovyan/notebooks/Vento_Lab/CVID/202009_new_analysis_revision/CITE_all_samples_analysis/CVID/scTranscriptomics_CITE/limma_DEG/validation_cohort_20210308/Ib_vs_healthy/20210308_' + ct + '_Ib_Freiburg_vs_' + ct + '_CONTROL_limma_DEGs_validation_cohort.csv')
    # adding 'cluster' column on the cell type this table is produced for
    limma_DE_tables[ct]['cluster'] = [ct]*len(limma_DE_tables[ct])
# Out:
# B_cells_memory
# B_cells_memory_activated
# B_cells_naive
# B_cells_naive_activated
# MAIT_cells
# Macrophages
# Monocytes_classical
# Monocytes_intermediate
# Monocytes_non-classical
# NK_CD16_bright
# NK_CD16_bright_activated
# NK_CD56_bright
# NK_CD56_bright_activated
# Plasma_cells
# Precursor_cells
# T4_activated
# T4_memory
# T4_naive
# T8_activated
# T8_naive
# TCM_CD8+
# TEM_CD8+
# TMRA_CD8+
# T_gd
# T_regs
# cDC1
# cDC2
# iNKT_cells
# pDC

# %%
limma_DE_tables['B_cells_memory']
# Out:
#                              Gene     logFC       P.Value     adj.P.Val  \
# 0                             IgD  1.023776  2.592023e-32  3.952057e-28
# 1      CD73(Ecto-5'-nucleotidase) -0.958522  2.139729e-22  1.631222e-18
# 2                      AC079767.4  0.384022  3.641864e-12  1.850917e-08
# 3                           IGHG3  0.311110  5.833035e-12  1.876685e-08
# 4                             IgA -0.543810  6.154275e-12  1.876685e-08
# ...                           ...       ...           ...           ...
# 15242                     C21orf2  0.000019  9.992583e-01  9.995205e-01
# 15243                      INTS10  0.000025  9.994488e-01  9.995509e-01
# 15244                       NFXL1 -0.000012  9.994504e-01  9.995509e-01
# 15245                       GCNT1 -0.000010  9.994853e-01  9.995509e-01
# 15246                        PIGN  0.000005  9.997243e-01  9.997243e-01
#
#        AveExpr_cluster  AveExpr_rest  percentExpr_cluster  percentExpr_rest  \
# 0             2.132361      1.108585             0.821826          0.565217
# 1             1.089468      2.047991             0.550111          0.735178
# 2             0.724130      0.340108             0.409800          0.221344
# 3             0.505015      0.193905             0.309577          0.128458
# 4             0.110669      0.654480             0.048998          0.175889
# ...                ...           ...                  ...               ...
# 15242         0.085207      0.085188             0.077951          0.071146
# 15243         0.252995      0.252970             0.191537          0.187747
# 15244         0.049903      0.049915             0.035635          0.041502
# 15245         0.036916      0.036926             0.028953          0.027668
# 15246         0.041451      0.041446             0.031180          0.031621
#
#               cluster
# 0      B_cells_memory
# 1      B_cells_memory
# 2      B_cells_memory
# 3      B_cells_memory
# 4      B_cells_memory
# ...               ...
# 15242  B_cells_memory
# 15243  B_cells_memory
# 15244  B_cells_memory
# 15245  B_cells_memory
# 15246  B_cells_memory
#
# [15247 rows x 9 columns]

# %%
# without any filtering
joint_DE_table = pd.concat(limma_DE_tables.values())

# %%
joint_DE_table
# Out:
#                              Gene     logFC       P.Value     adj.P.Val  \
# 0                             IgD  1.023776  2.592023e-32  3.952057e-28
# 1      CD73(Ecto-5'-nucleotidase) -0.958522  2.139729e-22  1.631222e-18
# 2                      AC079767.4  0.384022  3.641864e-12  1.850917e-08
# 3                           IGHG3  0.311110  5.833035e-12  1.876685e-08
# 4                             IgA -0.543810  6.154275e-12  1.876685e-08
# ...                           ...       ...           ...           ...
# 10940                      HENMT1 -0.000066  9.993520e-01  9.996314e-01
# 10941                       MYD88  0.000108  9.993756e-01  9.996314e-01
# 10942                       LBHD1  0.000030  9.994487e-01  9.996314e-01
# 10943                       SRSF5 -0.000073  9.997225e-01  9.998138e-01
# 10944                      ALKBH3  0.000006  9.999393e-01  9.999393e-01
#
#        AveExpr_cluster  AveExpr_rest  percentExpr_cluster  percentExpr_rest  \
# 0             2.132361      1.108585             0.821826          0.565217
# 1             1.089468      2.047991             0.550111          0.735178
# 2             0.724130      0.340108             0.409800          0.221344
# 3             0.505015      0.193905             0.309577          0.128458
# 4             0.110669      0.654480             0.048998          0.175889
# ...                ...           ...                  ...               ...
# 10940         0.086109      0.086175             0.058824          0.048387
# 10941         0.269189      0.269081             0.147059          0.161290
# 10942         0.034850      0.034821             0.029412          0.032258
# 10943         1.159138      1.159211             0.588235          0.645161
# 10944         0.126933      0.126927             0.117647          0.096774
#
#               cluster
# 0      B_cells_memory
# 1      B_cells_memory
# 2      B_cells_memory
# 3      B_cells_memory
# 4      B_cells_memory
# ...               ...
# 10940             pDC
# 10941             pDC
# 10942             pDC
# 10943             pDC
# 10944             pDC
#
# [445062 rows x 9 columns]

# %%
save_path
# Out:
# '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202009_CVID_revision/'

# %%
joint_DE_table.to_csv(save_path + 'joint_DEGs_list_all_cell_types_for_cellphone_20210308_subanalysis_Freiburg_Ib_and_healthy_donors.csv')
